# %%
import numpy as np
import matplotlib.pylab as plt
import sys
import csv

# %% [markdown]
# # Problem 1

# %% [markdown]
# ## Derivative functions

# %%
# This is for problem 2, where y[0] is xdot, y[1] is xdouble dot
def y_prime(t, y):
    dydt = np.array([y[1] , -y[0]])
    return dydt

# This is for problem 3, where y[0] is xdot, y[1] is ydot, y[2] is xdouble dot, y[3] is ydouble dot
def der(t, y):
    dydt = np.array([y[2],y[3],-y[0]/((1 + y[0]**2 + y[1]**2)**(3/2)),-y[1]/((1 + y[0]**2 + y[1]**2)**(3/2))])
    return dydt

# %% [markdown]
# ## Euler's Method

# %%
# inputs are initial conditions, derivative, start time, end time, number of steps to take
def Euler(y, dydt, t_i, t_f, n_steps):
    # this initializes the process, and creates a storage y_s for all our values as we integrate 
    t = t_i
    y_s1 = []
    
    # this is one step of Euler: takes in function, derivative, start and stop time, and number of steps
    # I am using steps instead of the step size to avoid float math errors. This, combined with a less than
    # condition (instead of less than or equal to) in the loop below achieve that.
    def babyEuler(y, dydt, t_i, t_f, n_steps):
        y = np.array(y)
        h = (t_f - t_i) / n_steps
        y_n1 = y + (h * dydt(t, y))
        return h, y_n1;

    # while we are in the time interval we integrate
    while t < t_f:
        dt, y_new = babyEuler(y, dydt, t_i, t_f, n_steps)
        y_s1.append(y_new)
        y = y_new
        t += dt
    
    last = y[0] # saving the last value as a separate entity to compare the methods later
    y_a1 = np.array(y_s1) # going from list to array to plot things later
    
    
    return last, y_a1;

# %% [markdown]
# ## Runge-Kutta Method

# %%
# inputs are initial conditions, derivative, start time, end time, number of steps to take
def RungeKutta(y, dydt, t_i, t_f, n_steps):
    # this initializes the process, and creates a storage y_s for all our values as we integrate
    t = t_i
    y_s2 = []
    # this is one step of rk4: takes in function, derivative, start and stop time, and number of steps
    # I am using steps instead of the step size to avoid float math errors. This, combined with a less than
    # condition (instead of less than or equal to) in the loop below achieve that.
    def baby_rk4(y, dydt, t_i, t_f, n_steps):
        h = (t_f - t_i) / n_steps
        k1 = h * dydt(t, y);
        k2 = h * dydt(t + (h/2), y + (k1 / 2));
        k3 = h * dydt(t + (h/2), y + (k2 / 2));
        k4 = h * dydt(t + h, y + k3);
        y_n1 = y + (k1 / 6) + (k2 / 3) + (k3 / 3) + (k4 / 6);
        return h, y_n1;


    #rk4 on our interval, saving all values and returning the last one
    while t < t_f:
        dt, y_new = baby_rk4(y, dydt, t_i, t_f, n_steps)
        y_s2.append(y_new)
        y = y_new
        t += dt
        
    last = y[0] # saving the last value as a separate entity to compare the methods later
    y_b1 = np.array(y_s2) # going from list to array to plot things later

    return last, y_b1;

# %% [markdown]
# ## Leapfrog Method

# %%
# inputs are initial conditions, derivative, start time, end time, number of steps to take
def LeapFrog(y, dydt, t_i, t_f, n_steps):
    # this initializes the process, and creates a storage y_s for all our values as we integrate
    t = t_i
    y_s3 = []
    
    # this is one step of Leapfrog: takes in function, derivative, start and stop time, and number of steps
    # I am using steps instead of the step size to avoid float math errors. This, combined with a less than
    # condition (instead of less than or equal to) in the loop below achieve that.
    def tadpole(y, dydt, t_i, t_f, n_steps):
        h = (t_f - t_i) / n_steps
        
        
        return h, y_n1 # I think???
    
    while t < t_f:
        dt, y_new = tadpole(y, dydt, t_i, t_f, n_steps)
        y_s2.append(y_new)
        y = y_new
        t += dt
        
    last = y[0] # savin the last value as a separate entity to compare the methods later
    y_c1 = np.array(y_s3) # going from list to array to plot things later
    
    
    return last, y_c1;

# %% [markdown]
# # Problem 2

# %% [markdown]
# ## Part a

# %% [markdown]
# All our h's in order: h = 1, 0.3, 0.1, 0.03, 0.01. \
# Corresponding n_steps =  30, 100, 300, 1000, 3000.

# %% [markdown]
# ### Euler

# %%
y0 = [0,1]; # initial condition
y = y0;
dydt = y_prime; # correct ODE
t_i = 0; # start time
t_f = 30; # end time
[E1, Eplot1] = Euler(y, dydt, t_i, t_f, 30);
[E2, Eplot2] = Euler(y, dydt, t_i, t_f, 100);
[E3, Eplot3] = Euler(y, dydt, t_i, t_f, 300);
[E4, Eplot4] = Euler(y, dydt, t_i, t_f, 1000);
[E5, Eplot5] = Euler(y, dydt, t_i, t_f, 3000);

# %% [markdown]
# ### Runge-Kutta

# %%
y0 = [0,1]; # initial condition
y = y0;
dydt = y_prime; # correct oDE
t_i = 0; # start time
t_f = 30; # end time
[R1, Rplot1] = RungeKutta(y, dydt, t_i, t_f, 30);
[R2, Rplot2] = RungeKutta(y, dydt, t_i, t_f, 100);
[R3, Rplot3] = RungeKutta(y, dydt, t_i, t_f, 300);
[R4, Rplot4] = RungeKutta(y, dydt, t_i, t_f, 1000);
[R5, Rplot5] = RungeKutta(y, dydt, t_i, t_f, 3000);

# %% [markdown]
# ### Leapfrog

# %%
y0 = [0,1]; # initial condition
y = y0;
dydt = y_prime; # correct oDE
t_i = 0; # start time
t_f = 30; # end time
[F1, Fplot1] = LeapFrog(y, dydt, t_i, t_f, 30);
[F2, Fplot2] = LeapFrog(y, dydt, t_i, t_f, 100);
[F3, Fplot3] = LeapFrog(y, dydt, t_i, t_f, 300);
[F4, Fplot4] = LeapFrog(y, dydt, t_i, t_f, 1000);
[F5, Fplot5] = LeapFrog(y, dydt, t_i, t_f, 3000);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-198-f161913447cb> in <module>
#       4 t_i = 0; # start time
#       5 t_f = 30; # end time
# ----> 6 [F1, Fplot1] = LeapFrog(y, dydt, t_i, t_f, 30);
#       7 [F2, Fplot2] = LeapFrog(y, dydt, t_i, t_f, 100);
#       8 [F3, Fplot3] = LeapFrog(y, dydt, t_i, t_f, 300);
#
# <ipython-input-163-f4e68f965061> in LeapFrog(y, dydt, t_i, t_f, n_steps)
#      15
#      16     while t < t_f:
# ---> 17         h_new, y_new = tadpole(y, dydt, t_i, t_f, n_steps)
#      18         y_s2.append(y_new)
#      19         y = y_new
#
# <ipython-input-163-f4e68f965061> in tadpole(y, dydt, t_i, t_f, n_steps)
#      12
#      13
# ---> 14         return h, y_n1 # I think???
#      15
#      16     while t < t_f:
#
# NameError: name 'y_n1' is not defined

# %% [markdown]
# Outputs organized:

# %%
Eulernumbers = [E1, E2, E3, E4, E5]
h = [1, 0.3, 0.1, 0.03, 0.01]
Rungenumbers = [R1, R2, R3, R4, R5]
h = [1, 0.3, 0.1, 0.03, 0.01]
Frognumbers = [R1, R2, R3, R4, R5]

print("Euler's Method:")
i = 0
while i<5:
    print(f"For t=30, y = {Eulernumbers[i]} for h = {h[i]}.")
    i += 1
    
print("Runge-Kutta Method:")
i = 0
while i<5:
    print(f"For t=30, y = {Rungenumbers[i]} for h = {h[i]}.")
    i += 1
    
print("Leapfrog Method:")
i = 0
while i<5:
    print(f"For t=30, y = {Frognumbers[i]} for h = {h[i]}.")
    i += 1
# Out:
# Euler's Method:
# For t=30, y = -32768.0 for h = 1.
# For t=30, y = -56.89806958384431 for h = 0.3.
# For t=30, y = -4.441582028306229 for h = 0.1.
# For t=30, y = -1.5513413829219396 for h = 0.03.
# For t=30, y = -1.1480989935077213 for h = 0.01.
# Runge-Kutta Method:
# For t=30, y = -0.8323631222462097 for h = 1.
# For t=30, y = -0.9878375115680561 for h = 0.3.
# For t=30, y = -0.9880334104769614 for h = 0.1.
# For t=30, y = -0.988031650317372 for h = 0.03.
# For t=30, y = -0.9880316244578938 for h = 0.01.
# Leapfrog Method:
# For t=30, y = -0.8323631222462097 for h = 1.
# For t=30, y = -0.9878375115680561 for h = 0.3.
# For t=30, y = -0.9880334104769614 for h = 0.1.
# For t=30, y = -0.988031650317372 for h = 0.03.
# For t=30, y = -0.9880316244578938 for h = 0.01.

# %% [markdown]
# ### Comments

# %% [markdown]
# The further we go, the more unstable Euler becomes, as can be seen from this graph:

# %%
# subplot this!!!
# plotting times against functions, times labeled txx, with a being Eueler, b being Leapfrog, c is RK4

# Euler graphing
taa = np.linspace(0,30,30);
tba = np.linspace(0,30,100);
tca = np.linspace(0,30,300);
tda = np.linspace(0,30,1000);
tea = np.linspace(0,30,3000);

#plt.plot(taa, Eplot1[:,1]) # i comment this out because the other step estimates can't be seen otherwise
plt.plot(tba, Eplot2[:,1])
plt.plot(tca, Eplot3[:,1])
plt.plot(tda, Eplot4[:,1])
plt.plot(tea, Eplot5[:,1])
# this is the actual function, with max amount of points used for t
plt.plot(tea, np.cos(tea), linewidth=3, color='green');

# %%
# Runge-Kutta graphing
tab = np.linspace(0,30, 30)
tbb = np.linspace(0,30, 100)
tcb = np.linspace(0,30, 300)
tdb = np.linspace(0,30, 1000)
teb = np.linspace(0,30, 3000)

plt.plot(tab, Rplot1[:,1])
plt.plot(tbb, Rplot2[:,1])
plt.plot(tcb, Rplot3[:,1])
plt.plot(tdb, Rplot4[:,1])
plt.plot(teb, Rplot5[:,1])
# this is actual function, in green
plt.plot(teb, np.cos(teb),linewidth=2, color='green');

# %%
# Leapfrog graphing
tac = np.linspace(0,30, 30)
tbc = np.linspace(0,30, 100)
tcc = np.linspace(0,30, 300)
tdc = np.linspace(0,30, 1000)
tec = np.linspace(0,30, 3000)

plt.plot(tab, Fplot1[:,1])
plt.plot(tbb, Fplot2[:,1])
plt.plot(tcb, Fplot3[:,1])
plt.plot(tdb, Fplot4[:,1])
plt.plot(teb, Fplot5[:,1])
# this is actual function, in green
plt.plot(tec, np.cos(tec),linewidth=3, color='green');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-197-3b364c21b65d> in <module>
#       6 tec = np.linspace(0,30, 3000)
#       7
# ----> 8 plt.plot(tab, Fplot1[:,1])
#       9 plt.plot(tbb, Fplot2[:,1])
#      10 plt.plot(tcb, Fplot3[:,1])
#
# NameError: name 'Fplot1' is not defined

# %% [markdown]
# ## Part b

# %%
#Euler and rk plots, work
hlogged = np.log10(h)
Euler_error = np.log10(np.abs(Eulernumbers - np.cos(30)))
rk4_error = np.log10(np.abs(Rungenumbers - np.cos(30)))
Frog_error = np.log10(np.abs(Frognumbers - np.cos(30)))
plt.plot(hlogged, Euler_error, color='blue');
plt.plot(hlogged,rk4_error, color='red');
#plot.plot(hlogged, Frog_error, color='green')

# %% [markdown]
# # Problem 3

# %%
y0 = [1, 0, 0, 0.3]; # initial condition in the form [x, y, dx, dy]
y = y0;
dydt = der; # correct ODE
t_i = 0; # start time
t_f = 100; # end time
[R1, Rplot1] = RungeKutta(y, dydt, t_i, t_f, 30);
[R2, Rplot2] = RungeKutta(y, dydt, t_i, t_f, 100);
[R3, Rplot3] = RungeKutta(y, dydt, t_i, t_f, 300);
[R4, Rplot4] = RungeKutta(y, dydt, t_i, t_f, 1000);
[R5, Rplot5] = RungeKutta(y, dydt, t_i, t_f, 3000);

# %%
# x vs y plot of all the rk's steps
plt.plot(Rplot1[:,0], Rplot1[:,1]);
plt.plot(Rplot2[:,0], Rplot2[:,1]);
plt.plot(Rplot3[:,0], Rplot3[:,1]);
plt.plot(Rplot4[:,0], Rplot4[:,1]);
plt.plot(Rplot5[:,0], Rplot5[:,1]);

# %% [markdown]
# #energy plot

# %%
tac = np.linspace(0,100, 0.003333333333)
plt.plot(Rplot5[:,0], Rplot5[:,1]);

Phi = -1/ np.sqrt(1 + Rplot5[:,0]**2 + Rplot5[:,1]**2)
Energy = (Rplot1[2]**2 + Rplot1[3]**2) / (2 + Phi)
plt.plot(tac, Energy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-9bd23765681c> in <module>
#       3
#       4 Phi = -1/ np.sqrt(1 + Rplot5[:,0]**2 + Rplot5[:,1]**2)
# ----> 5 Energy = (Rplot1[2]**2 + Rplot1[3]**2) / (2 + Phi)
#       6 plt.plot(tac, Energy)
#
# ValueError: operands could not be broadcast together with shapes (4,) (3001,)
